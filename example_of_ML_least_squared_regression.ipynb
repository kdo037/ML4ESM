# %% [markdown]
# <a href="https://colab.research.google.com/github/kdo037/ML4ESM/blob/main/example_of_ML_least_squared_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 100, 100)

# %%
y = x + 500

# %%
noise = np.random.normal(0, 10, y.shape)

# %%
y_noise = np.subtract(y, noise)

# %%
plt.scatter(x, y_noise)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# initial theta0 = 0.0 1and theta1 = 0.01
b = 0.1
w = 0.1

# learning rate alpha = 0.01
a = 0.000001

# %%
for i in range(1, 20000):
    # compute predicted y_hat = theta0 + theta1*x
    y_hat = b + w*x

    # compute the loss function for theta0
    l0 = np.sum(y_hat-y)
    l1 = np.sum(np.dot((y_hat-y_noise), x))

    b = b - a*l0
    w = w - a*l1

print('y_hat = ', round(b, 2), ' + ', round(w, 2), 'x')
y_hat = b + w*x
plt.scatter(x, y_noise)
plt.plot(x, y_hat, 'red')
print('Loss: ' + str(l0)[0:6])
# Out:
# y_hat =  502.9  +  0.94 x
# Loss: -33.69
